# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
df[df['Pclass'] == 3].shape
# Out:
# (491, 12)

# %%
df[(df['Survived'] == 0) & (df['Pclass'] == 3)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 12            13         0       3            Saundercock, Mr. William Henry
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
(372/491)*100         # pclass in 2 and dead
# Out:
# 75.76374745417516

# %%
df[df['Pclass']==2].shape
# Out:
# (184, 12)

# %%
df[(df['Survived'] == 0) & (df['Pclass'] == 2)]
# Out:
#      PassengerId  Survived  Pclass  \
# 20            21         0       2
# 33            34         0       2
# 41            42         0       2
# 70            71         0       2
# 72            73         0       2
# ..           ...       ...     ...
# 854          855         0       2
# 861          862         0       2
# 864          865         0       2
# 883          884         0       2
# 886          887         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 70                          Jenkin, Mr. Stephen Curnow    male  32.0      0
# 72                                Hood, Mr. Ambrose Jr    male  21.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
(97/184)*100
# Out:
# 52.71739130434783

# %%
df[df['Pclass']==1].shape
# Out:
# (216, 12)

# %%
df[(df['Survived'] == 0) & (df['Pclass'] == 1)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 30            31         0       1              Uruchurtu, Don. Manuel E
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# 35            36         0       1        Holverson, Mr. Alexander Oskar
# ..           ...       ...     ...                                   ...
# 806          807         0       1                Andrews, Mr. Thomas Jr
# 815          816         0       1                      Fry, Mr. Richard
# 822          823         0       1       Reuchlin, Jonkheer. John George
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
#
#       Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
(80/216)*100 # pclass is 1 dead
# Out:
# 37.03703703703704

# %%
(372/491)*100         # pclass in 2 and dead
# Out:
# 75.76374745417516

# %%
(372/491)*100        # pclass 9n 3 an dead
# Out:
# 75.76374745417516

# %%
# new columns

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df['New']= 'Hello'

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    New
# 0      0         A/5 21171   7.2500   NaN        S  Hello
# 1      0          PC 17599  71.2833   C85        C  Hello
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Hello
# 3      0            113803  53.1000  C123        S  Hello
# ...

# %%
df['New']='python'

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     New
# 0      0         A/5 21171   7.2500   NaN        S  python
# 1      0          PC 17599  71.2833   C85        C  python
# 2      0  STON/O2. 3101282   7.9250   NaN        S  python
# 3      0            113803  53.1000  C123        S  python
# ...

# %%
df['New_age'] = df['Age'] + 10

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     New  New_age
# 0      0         A/5 21171   7.2500   NaN        S  python     32.0
# 1      0          PC 17599  71.2833   C85        C  python     48.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  python     36.0
# ...

# %%
df['AGE_PCLASS'] = df['Age'] + df['Pclass']

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     New  New_age  \
# 0      0         A/5 21171   7.2500   NaN        S  python     32.0
# 1      0          PC 17599  71.2833   C85        C  python     48.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  python     36.0
# ...

# %%
def square(a):
    square = a * a
    if square > 100:
        return 'Grater than 100'
    else:
        return 'Less than 100'

# %%
df['Square_condn'] = df['Age'].apply(square)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     New  New_age  \
# 0      0         A/5 21171   7.2500   NaN        S  python     32.0
# 1      0          PC 17599  71.2833   C85        C  python     48.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  python     36.0
# ...

# %%
def square(a):
    square = a * a
    return square

# %%
df['Square_condn'] = df['Age'].apply(square)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     New  New_age  \
# 0      0         A/5 21171   7.2500   NaN        S  python     32.0
# 1      0          PC 17599  71.2833   C85        C  python     48.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  python     36.0
# ...

# %%
# Remove columns

# %%
df.drop(columns=['Square_condn'], axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     New  New_age  \
# 0      0         A/5 21171   7.2500   NaN        S  python     32.0
# 1      0          PC 17599  71.2833   C85        C  python     48.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  python     36.0
# ...

# %%
removed_column = df.drop(columns=['Square_condn'], axis=1)

# %%
removed_column.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     New  New_age  \
# 0      0         A/5 21171   7.2500   NaN        S  python     32.0
# 1      0          PC 17599  71.2833   C85        C  python     48.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  python     36.0
# ...

# %%
df.drop(columns = ['New'], axis = 1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     New  New_age  \
# 0      0         A/5 21171   7.2500   NaN        S  python     32.0
# 1      0          PC 17599  71.2833   C85        C  python     48.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  python     36.0
# ...

# %%
removed_column = df.drop(columns = ['New'], axis = 1)

# %%
removed_column.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_age  AGE_PCLASS  \
# 0      0         A/5 21171   7.2500   NaN        S     32.0        25.0
# 1      0          PC 17599  71.2833   C85        C     48.0        39.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S     36.0        29.0
# ...

# %%
removed_column = df.drop(columns = ['New_age'], axis = 1)

# %%
removed_column.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     New  AGE_PCLASS  \
# 0      0         A/5 21171   7.2500   NaN        S  python        25.0
# 1      0          PC 17599  71.2833   C85        C  python        39.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  python        29.0
# ...

# %%
removed_column = df.drop(columns = ['New'] ,axis= 1)

# %%
removed_column.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_age  AGE_PCLASS  \
# 0      0         A/5 21171   7.2500   NaN        S     32.0        25.0
# 1      0          PC 17599  71.2833   C85        C     48.0        39.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S     36.0        29.0
# ...

# %%
def gender(a):
    if a == 'male':
        return 1
    elif a == 'female':
        return 0
    else:
        return 'Error'

# %%
df['Gender_Con'] = df['Sex'].apply(gender)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df['Gender_Con'] = df['Sex'].apply(gender)
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#    PassengerId  Survived       Pclass  \
# 0            1         0  Third class
# 1            2         1  Third class
# 2            3         1  Third class
# 3            4         1  Third class
# 4            5         0  Third class
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     New  New_age  \
# 0      0         A/5 21171   7.2500   NaN        S  python     32.0
# 1      0          PC 17599  71.2833   C85        C  python     48.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  python     36.0
# ...

# %%
df.drop(columns=['Gender_Con'],axis=1,inplace=True)  # Do changes permanantly

# %%
# Write function for Pclass and write in text in new column ['First class, Second class']  21/02/2025
